# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('telco_customer_churn.csv')

# %%
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ### Welcome to Day 9 Homework. Please answer the questions below!

# %% [markdown]
# 1. Buanglah baris dengan `tenure` samadengan 0 (jadi, data yang akan kita analisa di PR ini adalah baris-baris dengan `tenure` TIDAK samadengan 0). Ada berapa baris yang sekarang tersedia di data kita?
#
# 2. Bagi customer yang ***TIDAK MEMILIKI PARTNER*** dan ***TIDAK MEMILIKI DEPENDENTS***, berapa ***rata-rata*** dari `tenure` mereka?
#
# 3. Bagi customer yang ***MEMILIKI PARTNER*** dan ***TIDAK MEMILIKI DEPENDENTS***, berapa maksimal `MonthlyCharges` yang tercata?
#
# 4. Berapa banyak customer yang ***TIDAK MEMILIKI PARTNER*** namun ***MEMILIKI DEPENDENTS***?
#
# 5. Berapa rata-rata ***TOTAL CHARGES*** dari customer ***NON-SENIOR CITIZEN*** (Senior Citizen = 0) yang memiliki ***PHONE SERVICE*** dan memiliki ***INTERNET SERVICE FIBER OPTIC***?

# %% [markdown]
# #### Silakan menuliskan kode untuk menjawab 5 pertanyaan di atas...

# %%
## NOMOR 1

df_update = df[df['tenure']!=0]
df_update
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
## NOMOR 2

df_update_no_partner_no_dependents = df_update[(df_update['Partner']=='No')&(df_update['Dependents']=='No')]
df_update_no_partner_no_dependents
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# ...          ...     ...            ...     ...        ...     ...
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1             Yes                No             DSL                  Yes  ...
# ...

# %%
df_update_no_partner_no_dependents['tenure'].mean()
# Out:
# 23.303353658536587

# %%
## NOMOR 3

df_update_have_partner_no_dependents = df_update[(df_update['Partner']=='Yes')&(df_update['Dependents']=='No')]
df_update_have_partner_no_dependents
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# 21    1680-VDCWW    Male              0     Yes         No      12
# 23    3638-WEABW  Female              0     Yes         No      58
# ...          ...     ...            ...     ...        ...     ...
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7024  7398-LXGYX    Male              0     Yes         No      44
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7031  3605-JISKB    Male              1     Yes         No      55
# 7041  8361-LTMKD    Male              1     Yes         No       4
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# ...

# %%
df_update_have_partner_no_dependents['MonthlyCharges'].max()
# Out:
# 118.6

# %%
## NOMOR 4

df_update_no_partner_have_dependents = df_update[(df_update['Partner']=='No')&(df_update['Dependents']=='Yes')]
df_update_no_partner_have_dependents
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6     1452-KIOVK    Male              0      No        Yes      22
# 9     6388-TABGU    Male              0      No        Yes      62
# 17    9959-WOFKT    Male              0      No        Yes      71
# 29    8773-HHUOZ  Female              0      No        Yes      17
# 74    5630-AHZIL  Female              0      No        Yes       3
# ...          ...     ...            ...     ...        ...     ...
# 6946  9013-AQORL  Female              0      No        Yes      48
# 6966  6598-KELSS    Male              0      No        Yes      50
# 6979  5351-QESIO    Male              0      No        Yes       1
# 6984  6447-GORXK    Male              0      No        Yes      31
# 6995  7164-BPTUT    Male              0      No        Yes      57
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 6             Yes               Yes     Fiber optic             No  ...
# ...

# %%
## NOMOR 5

df_update_no_5 = df_update[(df_update['SeniorCitizen']==0)&(df_update['PhoneService']=='Yes')&(df_update['InternetService']== 'Fiber optic')]
df_update_no_5
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 8     7892-POOKP  Female              0     Yes         No      28
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...          ...     ...            ...     ...        ...     ...
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 4             Yes            No     Fiber optic             No  ...
# ...

# %%
df_update_no_5['TotalCharges'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 2265 entries, 4 to 7042
# Series name: TotalCharges
# Non-Null Count  Dtype
# --------------  -----
# 2265 non-null   object
# dtypes: object(1)
# memory usage: 35.4+ KB

# %%
total_charges = pd.to_numeric(df_update_no_5['TotalCharges'], errors = 'coerce')
total_charges
# Out:
# 4        151.65
# 5        820.50
# 6       1949.40
# 8       3046.05
# 12      5681.10
#          ...
# 7033    2625.25
# 7034    6886.25
# 7035    1495.10
# 7039    7362.90
# 7042    6844.50
# Name: TotalCharges, Length: 2265, dtype: float64

# %%
np.round((total_charges).mean())
# Out:
# 3226.0

# %% [markdown]
# ### Silakan menjawab di bawah ini:

# %% [markdown]
# #### Soal 1:
# Buanglah baris dengan tenure samadengan 0 (jadi, data yang akan kita analisa di PR ini adalah baris-baris dengan tenure TIDAK samadengan 0). Ada berapa baris yang sekarang tersedia di data kita?
#
# #### Jawaban: ada 7032 baris

# %% [markdown]
# #### Soal 2:
# Bagi customer yang TIDAK MEMILIKI PARTNER dan TIDAK MEMILIKI DEPENDENTS, berapa rata-rata dari tenure mereka?
#
# #### Jawaban: Rata-rata tenure mereka adalah 23.303353658536587

# %% [markdown]
# #### Soal 3:
# Bagi customer yang MEMILIKI PARTNER dan TIDAK MEMILIKI DEPENDENTS, berapa maksimal MonthlyCharges yang tercatat?
#
# #### Jawaban: 118.6

# %% [markdown]
# #### Soal 4:
# Berapa banyak customer yang TIDAK MEMILIKI PARTNER namun MEMILIKI DEPENDENTS?
#
# #### Jawaban: 359 orang

# %% [markdown]
# #### Soal 5:
# Berapa rata-rata TOTAL CHARGES dari customer NON-SENIOR CITIZEN (Senior Citizen = 0) yang memiliki PHONE SERVICE dan memiliki INTERNET SERVICE FIBER OPTIC?
#
# #### Jawaban: 3226.0

# %% [markdown]
# note: submit pertama di tanggal 28 april, nomor 5 mengasumsikan pernyataan dalam kurung yg ada di soal adalah menyatakan kalau non senior citizen nilainya 0 di kolom senior citizen. Lalu di tanggal 1 mei cek ulang ternyata pernyataan dalam kurung tersebut bisa saja menyatakan bahwa senior citizen = 0 artinya non senior citizen = 1. sempat submit ulang dengan pernyataan kedua namun kembali di submit ulang dengan jawaban pertama karna soal yg ambigu dan saya mengacu pada nilai kebenaran 1 biasanya adalah yg benar atau tautologi dan 0 adalah kontradiksi.
#
# karna ini soalnya ambigu dan atau memang sayanya yang belum tau, mohon diberikan penjelasannya ya nanti.

# %% [markdown]
# # THANK YOUUUUUUUUU###
